# %%
from langchain_core.documents import Document
documents = [
    Document(
        page_content="Dogs are great companions, known for their loyalty and friendliness.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Cats are independent pets that often enjoy their own space.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Goldfish are popular pets for beginners, requiring relatively simple care.",
        metadata={"source": "fish-pets-doc"},
    ),
    Document(
        page_content="Parrots are intelligent birds capable of mimicking human speech.",
        metadata={"source": "bird-pets-doc"},
    ),
    Document(
        page_content="Rabbits are social animals that need plenty of space to hop around.",
        metadata={"source": "mammal-pets-doc"},
    ),
]

# %%
documents
# Out:
# [Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(metadata={'source': 'fish-pets-doc'}, page_content='Goldfish are popular pets for beginners, requiring relatively simple care.'),
#  Document(metadata={'source': 'bird-pets-doc'}, page_content='Parrots are intelligent birds capable of mimicking human speech.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Rabbits are social animals that need plenty of space to hop around.')]

# %%
# !pip install langchain_chroma
# Out:
# Collecting langchain_chroma
#   Using cached langchain_chroma-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: chromadb<2.0.0,>=1.3.5 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain_chroma) (1.4.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain_chroma) (1.2.9)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain_chroma) (2.3.1)
# Requirement already satisfied: build>=1.0.3 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.4.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.12.5)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.40.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.51.0)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (4.67.2)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.21.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (3.11.6)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (14.3.2)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from chromadb<2.0.0,>=1.3.5->langchain_chroma) (4.26.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain_chroma) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain_chroma) (0.6.7)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain_chroma) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain_chroma) (0.14.0)
# Requirement already satisfied: pyproject_hooks in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.2.0)
# Requirement already satisfied: colorama in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.4.6)
# Requirement already satisfied: anyio in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (4.12.1)
# Requirement already satisfied: certifi in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.0.9)
# Requirement already satisfied: idna in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain_chroma) (3.0.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.9.0)
# Requirement already satisfied: requests in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.32.5)
# Requirement already satisfied: requests-oauthlib in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.6.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.10)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain_chroma) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain_chroma) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain_chroma) (0.25.0)
# Requirement already satisfied: coloredlogs in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain_chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain_chroma) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain_chroma) (6.33.5)
# Requirement already satisfied: sympy in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (8.7.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.60b1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from posthog<6.0.0,>=2.4.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic>=1.9->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2.19.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.3.7)
# Requirement already satisfied: click>=8.0.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.2.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain_chroma) (16.0)
# Requirement already satisfied: filelock in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain_chroma) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain_chroma) (2026.1.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.2.0)
# Requirement already satisfied: typer-slim in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.21.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (3.4.4)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain_chroma) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain_chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain_chroma) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\mkshc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain_chroma) (3.5.4)
# Using cached langchain_chroma-1.1.0-py3-none-any.whl (12 kB)
# Installing collected packages: langchain_chroma
# Successfully installed langchain_chroma-1.1.0
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\mkshc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv
load_dotenv()

from langchain_groq import ChatGroq
groq_api_key = os.getenv("GROQ_API_KEY")

os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")

llm = ChatGroq(groq_api_key = groq_api_key,model = " llama3")

# %%
## VectorStores
from langchain_chroma import Chroma
